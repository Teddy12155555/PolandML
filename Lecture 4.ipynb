# %% [markdown]
# # Iris data set

# %% [markdown]
# 1) builded in data:

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
iris=load_iris()
IrisData=iris['data']
IrisTarget=iris['target']
print(type(IrisData))
print(IrisData.shape)
# will do it better later ;)
I0=IrisData[:,3]
I0=[I0[IrisTarget==0],I0[IrisTarget==1],I0[IrisTarget==2]]
#print("here:")
#print(iris)
plt.boxplot(I0,labels=iris['target_names'])
plt.title('Petal width (PW)')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# (150, 4)

# %%
def ScatterPlot(Data,fsize):
    plt.figure(figsize=fsize)
    nn=Data.shape[1]
    # Label the diagonal subplots...
    names=['SL','SW','PL','PW']
    fig, axes = plt.subplots(nrows=nn, ncols=nn, figsize=fsize)
    fig.subplots_adjust(hspace=0.05, wspace=0.05)
    for i, label in enumerate(names):
        axes[i,i].annotate(label, (0.5, 0.5), xycoords='axes fraction',ha='center', va='center')
    # Plot all the nn scatterplots
    for i in range(nn):
        for j in range(nn):
            if(i!=j):
                plt.subplot(nn,nn,nn*i+j+1)
                plt.scatter(IrisData[:,j],IrisData[:,i],c=IrisTarget)
    plt.show()
    
ScatterPlot(IrisData,(10,10))

# %% [markdown]
# 2) data imported from Kaggle:

# %%
#Importing Package 
import sys
print('Python: {}'.format(sys.version))
import numpy
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import numpy as np
import warnings
dataset = pandas.read_csv('IRIS.csv')

#Printing DataFrame -only first 20 rows to understand what data look like
print(dataset.head(20))
#Data have 5 Columns ,First four are features and fifth is Classfication of the Iris type
# Out:
# Python: 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
#find unique classification/type of iris flower.
dataset['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#find no of rows for each Species.
print(dataset.groupby('species').size())
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
#Create DataFrame for each of 3 Species
setosa=dataset[dataset['species']=='Iris-setosa']
versicolor=dataset[dataset['species']=='Iris-versicolor']
virginica=dataset[dataset['species']=='Iris-virginica']

print("Setosa:")
print(setosa.describe())
print("Versicolor:")
print(versicolor.describe())
print("Virginica:")
print(virginica.describe())
# Out:
# Setosa:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
# Versicolor:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# ...

# %%
print(dataset.describe())
#count tells that all the 4 features have 150 rows
#in general, from mean we can say that sepal is larger than petal.
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
###############################Histogram# Plot all feature for all species###########################################################################
plt.figure()

fig,ax=plt.subplots(4,3,figsize=(17, 8))
setosa["sepal_length"].plot(kind="hist", ax=ax[0][0],label="setosa",color ='r',fontsize=10)
versicolor["sepal_length"].plot(kind="hist", ax=ax[0][1],label="versicolor",color='b',fontsize=10)
virginica["sepal_length"].plot( kind="hist",ax=ax[0][2],label="virginica",color='g',fontsize=10)

setosa["sepal_width"].plot(kind="hist", ax=ax[1][0],label="setosa",color ='r',fontsize=10)
versicolor["sepal_width"].plot(kind="hist", ax=ax[1][1],label="versicolor",color='b',fontsize=10)
virginica["sepal_width"].plot( kind="hist",ax=ax[1][2],label="virginica",color='g',fontsize=10)

setosa["petal_length"].plot(kind="hist", ax=ax[2][0],label="setosa",color ='r',fontsize=10)
versicolor["petal_length"].plot(kind="hist", ax=ax[2][1],label="versicolor",color='b',fontsize=10)
virginica["petal_length"].plot( kind="hist",ax=ax[2][2],label="virginica",color='g',fontsize=10)


setosa["petal_width"].plot(kind="hist", ax=ax[3][0],label="setosa",color ='r',fontsize=10)
versicolor["petal_width"].plot(kind="hist", ax=ax[3][1],label="versicolor",color='b',fontsize=10)
virginica["petal_width"].plot( kind="hist",ax=ax[3][2],label="virginica",color='g',fontsize=10)

plt.rcParams.update({'font.size': 10})
plt.tight_layout()

ax[0][0].set(title='sepal_length')
ax[0][1].set(title='sepal_length')
ax[0][2].set(title='sepal_length')
ax[1][0].set(title='sepal_width ')
ax[1][1].set(title='sepal_width ')
ax[1][2].set(title='sepal_width ')
ax[2][0].set(title='petal_length')
ax[2][1].set(title='petal_length ')
ax[2][2].set(title='petal_length')
ax[3][0].set(title='petal_width')
ax[3][1].set(title='petal_width')
ax[3][2].set(title='petal_width')

ax[0][0].legend()
ax[0][1].legend()
ax[0][2].legend()
ax[1][0].legend()
ax[1][1].legend()
ax[1][2].legend()
ax[2][0].legend()
ax[2][1].legend()
ax[2][2].legend()
ax[3][0].legend()
ax[3][1].legend()
ax[3][2].legend()


plt.show()
plt.close()



###########################################################################################################

# %%
colors=np.array(['r']*len(dataset))
# colors[dataset['species']=='Iris-setosa']='r' # assigned in previous line to all of the observations
colors[dataset['species']=='Iris-versicolor']='g'
colors[dataset['species']=='Iris-virginica']='b'
scatter_matrix(dataset,c=colors,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008F33DA0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Use seaborn to plot scatterplots

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier # for k-NN method
from sklearn.model_selection import train_test_split # for creating learn and train datasets

g = sns.pairplot(dataset, hue='species', markers='o')
plt.show()

# %% [markdown]
# ## Split data to learn and train set

# %%
X = dataset.drop(['species'], axis=1) # you can easily select only some variables
y = dataset['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (100, 4)
# (100,)
# (50, 4)
# (50,)

# %% [markdown]
# ## k-NN (k nearest neighbours) supervised classification

# %%
# experimenting with different k values
k_range = list(range(1,26,2))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for k-NN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()

# %%
# prediction with k=3, you can select better k
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
ytrain_pred=knn.predict(X_train)
names=dataset['species'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names)
pandas.DataFrame(Output_Train,names,names)
# Out:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa             32.0              0.0             0.0
# Iris-versicolor          0.0             34.0             1.0
# Iris-virginica           0.0              1.0            32.0

# %%
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %% [markdown]
# # Breast Cancer Wisconsin Data Set

# %%
#Importing Package 
import sys
print('Python: {}'.format(sys.version))
import numpy
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import numpy as np
import warnings
dataset = pandas.read_csv('wisconsin.csv')

#Printing DataFrame - only first 10 rows to understand what data look like
print(dataset.head(10))
# So many columns... classification is in diagnosis
# Out:
# Python: 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
# ...

# %%
#find unique classification/type.
dataset['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
#find no of rows for each type.
print(dataset.groupby('diagnosis').size())
# Out:
# diagnosis
# B    357
# M    212
# dtype: int64

# %%
#Create DataFrame for each type
M=dataset[dataset['diagnosis']=='M']
B=dataset[dataset['diagnosis']=='B']

print("Malignant:")
print(M.describe())
print("Benign:")
print(B.describe())
# Out:
# Malignant:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  2.120000e+02   212.000000    212.000000      212.000000   212.000000
# mean   3.681805e+07    17.462830     21.604906      115.365377   978.376415
# std    1.378965e+08     3.203971      3.779470       21.854653   367.937978
# min    8.670000e+03    10.950000     10.380000       71.900000   361.600000
# 25%    8.613450e+05    15.075000     19.327500       98.745000   705.300000
# 50%    8.953665e+05    17.325000     21.460000      114.200000   932.000000
# 75%    8.911290e+06    19.590000     23.765000      129.925000  1203.750000
# max    9.112962e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       212.000000        212.000000      212.000000           212.000000
# mean          0.102898          0.145188        0.160775             0.087990
# ...

# %%
print(dataset.describe())
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## Use seaborn for boxplots

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

for i in range(2,len(dataset.columns)):
    g = sns.boxplot(x="diagnosis", y=dataset.columns[i], data=dataset)
    plt.show()

# %%
# WARNING: extremely slow for the whole dataset! (to many subplots)
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# [1:15] below selects only first 13 variables (attributes), still slow!
g = sns.pairplot(dataset[dataset.columns[1:15]], hue='diagnosis', markers='x')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diagnosis'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-1ab7aedca448> in <module>
#      12
# ...

# %%
datasetN=dataset[dataset.columns[1:32]] # drop Unnamed column
X = datasetN.drop(['diagnosis'], axis=1)
y = datasetN['diagnosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (381, 30)
# (381,)
# (188, 30)
# (188,)

# %% [markdown]
# ## k-NN

# %%
# experimenting with different n values
k_range = list(range(1,26,2))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()

# %%
# prediction with k=3
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
ytrain_pred=knn.predict(X_train)
names=dataset['diagnosis'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names) # really bad: half of malignant predicted as benign!!!
#pandas.DataFrame(Output_Train,names,names)
# Out:
#       M      B
# M  60.0    2.0
# B   9.0  117.0

# %% [markdown]
# ## LDA (Linear Discriminant Analysis)

# %%
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
clf = LinearDiscriminantAnalysis()
clf.fit(X_train, y_train)  
y_pred=clf.predict(X_test)
ytrain_pred=clf.predict(X_train)
names=dataset['diagnosis'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names)
pandas.DataFrame(Output_Train,names,names)
# Out:
#        M      B
# M  132.0    0.0
# B   11.0  238.0

# %% [markdown]
# ## Quadratic Discriminant Analysis

# %%
import numpy as np
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
clf = QuadraticDiscriminantAnalysis()
clf.fit(X_train, y_train)  
y_pred=clf.predict(X_test)
ytrain_pred=clf.predict(X_train)
names=dataset['diagnosis'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names)
#pandas.DataFrame(Output_Train,names,names)
# Out:
#       M      B
# M  67.0    2.0
# B   2.0  117.0

# %% [markdown]
# ## Decision Trees

# %%
import numpy as np
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)  
y_pred=clf.predict(X_test)
ytrain_pred=clf.predict(X_train)
names=dataset['diagnosis'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names) # not so bad
#pandas.DataFrame(Output_Train,names,names) # 0 errors here mean: a little overfitted
# Out:
#       M      B
# M  64.0    9.0
# B   5.0  110.0

# %% [markdown]
# ## Neural network models

# %% [markdown]
# 1) Data is not normalized:

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier()
clf.fit(X_train, y_train)  
y_pred=clf.predict(X_test)
ytrain_pred=clf.predict(X_train)
names=dataset['diagnosis'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names)
#pandas.DataFrame(Output_Train,names,names) # really bad, everything in learning set is predicted as benign
# Out:
#       M      B
# M  63.0    6.0
# B   6.0  113.0

# %% [markdown]
# 2) Normalization (standardization)

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
# Don't cheat - fit only on training data
scaler.fit(X_train)  
X_train = scaler.transform(X_train)  
# apply same transformation to test data
X_test = scaler.transform(X_test)
# apply it also later on any data you want to make prediction on

# don't worry about warning here

# %% [markdown]
# hence once again neural networks on normalized data:

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier()
clf.fit(X_train, y_train)  
y_pred=clf.predict(X_test)
ytrain_pred=clf.predict(X_train)
names=dataset['diagnosis'].unique()
N=len(names)
Output=np.zeros([N,N])
Output_Train=np.zeros([N,N])
for i in range(N):
    for j in range(N):
        Output[i,j]=sum((y_pred==names[i])&(y_test==names[j]))
        Output_Train[i,j]=sum((ytrain_pred==names[i])&(y_train==names[j]))
pandas.DataFrame(Output,names,names) # much better now, results are good
#pandas.DataFrame(Output_Train,names,names)

# don't worry about warning
# Out:
# C:\Users\IVk241\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#       M      B
# M  67.0    1.0
# B   2.0  118.0

# %% [markdown]
# # Exercises
# 1) Try to use all the metods of supervised learning on iris dataset (you can also choose some other dataset from Kaggle, if you really want).<br>
# 2) Try to select only two variables for selected classification and still have accetable results.<br>

# %%
import sys
print('Python: {}'.format(sys.version))
import numpy
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import numpy as np
import warnings
dataset = pandas.read_csv('IRIS.csv')

#Printing DataFrame -only first 20 rows to understand what data look like
print(dataset.head(20))
#Data have 5 Columns ,First four are features and fifth is Classfication of the Iris type
# Out:
# Python: 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# ...
