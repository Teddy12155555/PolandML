# %%
#project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
filename = 'googleplaystore.csv' 
play = pd.read_csv(filename, encoding='utf8')
play.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
play.loc[play['App'] == 'Sketch - Draw & Paint']
# Out:
#                      App        Category  Rating Reviews Size     Installs  \
# 3  Sketch - Draw & Paint  ART_AND_DESIGN     4.5  215644  25M  50,000,000+
#
#    Type Price Content Rating        Genres  Last Updated         Current Ver  \
# 3  Free     0           Teen  Art & Design  June 8, 2018  Varies with device
#
#   Android Ver
# 3  4.2 and up

# %%
#play.fillna(0)

# %%
#sns.relplot(x='Rating',y='Installs', hue='Category', data=play)

# %%
test = pd.DataFrame(columns=['Category','Data'])
cat = play.groupby("Category")
cat.size()
sum(cat.size())
name = np.unique(play.Category)
test['Category'] = name
for i in range(len(name)):
    test['Data'][i] = len(cat.get_group(name[i]))
test
sns.relplot(x='Category',y='Data', data=test)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 6))
#plt.set_xticklabels(rotation=90)
plt.bar(test['Category'],test['Data'])
plt.xticks(rotation = 90)
plt.xlabel('Category')
plt.ylabel('Data number')
plt.savefig*
# Out:
# Text(0, 0.5, 'Data number')

# %%
rat = list(range(6))
for i in range(6):
    rat[i] =  play.loc[(play['Rating'] >=i)  &  (play['Rating']  <i+1)].copy()
    
other = play.loc[play['Rating'] == play['Rating'] ].copy()

# %%
#play['Installs'].replace({"+":''},regex=True)
print(play['Installs'][0].replace("+",''))
print(play['Installs'][0])
for i in range(len(play['Installs'])):
    play['Installs'][i].replace("+",'')
print(play['Installs'])
# Out:
# 10,000
# 10,000
# 0             10,000
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
# 5            50,000+
# 6            50,000+
# 7         1,000,000+
# 8         1,000,000+
# 9            10,000+
# 10        1,000,000+
# 11        1,000,000+
# 12       10,000,000+
# 13          100,000+
# 14          100,000+
# 15            5,000+
# 16          500,000+
# 17           10,000+
# 18        5,000,000+
# 19       10,000,000+
# 20          100,000+
# 21          100,000+
# 22          500,000+
# 23          100,000+
# 24           50,000+
# 25           10,000+
# 26          500,000+
# 27          100,000+
# 28           10,000+
# 29          100,000+
#             ...
# 10811           100+
# 10812         1,000+
# 10813        10,000+
# 10814        50,000+
# 10815       500,000+
# 10816           100+
# 10817       100,000+
# 10818        10,000+
# 10819         5,000+
# 10820         1,000+
# 10821            50+
# ...

# %%
np.nan == np.nan
# Out:
# False

# %%
test = play.groupby('Category')
name = play.Category.unique()
test.get_group(name[1])
sns.relplot(x='Category',y='Installs', hue='Rating', data=play)

#name

# %%
#test
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
newDF = pd.DataFrame(columns=['Category','Reviews','Genres'])
newDF['Category'] = pd.factorize(play['Category'])[0].astype(np.uint16).copy()
newDF['Reviews'] = play['Reviews'].copy()
newDF['Genres'] =  pd.factorize(play['Genres'].copy())[0].astype(np.uint16).copy() 
Y = play['Rating'].copy()
Y = round(Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(newDF, Y, test_size=0.33)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (7263, 3)
# (7263,)
# (3578, 3)
# (3578,)
