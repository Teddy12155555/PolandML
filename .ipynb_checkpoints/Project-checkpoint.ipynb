# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv('googleplaystore.csv',encoding='utf8')
Rating=dataset['Rating']
Reviews=dataset['Reviews']
Size=dataset['Size']
Category=dataset['Category']
Installs=dataset['Installs']
df1=pd.DataFrame(Category)
df1['Rating']=Rating.interpolate(method ='linear', limit_direction ='forward') 
df1['Reviews']=Reviews
df1['Size']=Size
df1['Installs']=Installs
df1['Installs'].replace(to_replace='+',value='')
Zuicha=df1[df1['Rating']<1.5]
Jicha=df1[df1['Rating']<2.0][df1[df1['Rating']<2.0]['Rating']>=1.5]
Jiaocha=df1[df1['Rating']<2.5][df1[df1['Rating']<2.5]['Rating']>=2.0]
Cha=df1[df1['Rating']<3.0][df1[df1['Rating']<3.0]['Rating']>=2.5]
Hao=df1[df1['Rating']<3.5][df1[df1['Rating']<3.5]['Rating']>=3.0]
Jiaohao=df1[df1['Rating']<4.0][df1[df1['Rating']<4.0]['Rating']>=3.5]
Jihao=df1[df1['Rating']<4.5][df1[df1['Rating']<4.5]['Rating']>=4.0]
Zuihao=df1[df1['Rating']<5.0][df1[df1['Rating']<5.0]['Rating']>=4.5]
Lis=[Zuicha,Jicha,Jiaocha,Cha,Hao,Jiaohao,Jihao,Zuihao]
for i in Lis:
    print(i.groupby('Category').count())
#    print(i.count())
df1['Installs'] = df1['Installs'].str.replace('+', "")
df1['Installs'] = df1['Installs'].str.replace(',','')
df1=df1[df1['Installs']!='Free']
df1['Installs']= pd.DataFrame(df1['Installs'],dtype=float)
df1['Installs']=Rating.interpolate(method ='linear', limit_direction ='forward') 
df1['Installs']=np.log(df1['Installs'])
df1['Reviews']= pd.DataFrame(df1['Reviews'],dtype=float)
df1['Reviews']=Rating.interpolate(method ='linear', limit_direction ='forward') 
df1['Reviews']=np.log(df1['Reviews'])
df1['Size'] = df1['Size'].str.replace('M', "")
df1['Size']=Rating.interpolate(method ='linear', limit_direction ='forward') 
df1
#These above all is all about how to deal with our data
# Out:
#                     Rating  Reviews  Size  Installs
# Category
# BUSINESS                 1        1     1         1
# COMMUNICATION            1        1     1         1
# DATING                   1        1     1         1
# FAMILY                   3        3     3         3
# FINANCE                  3        3     3         3
# GAME                     2        2     2         2
# HEALTH_AND_FITNESS       1        1     1         1
# MEDICAL                  3        3     3         3
# PRODUCTIVITY             1        1     1         1
# TOOLS                    4        4     4         4
#                      Rating  Reviews  Size  Installs
# Category
# BUSINESS                  3        3     3         3
# DATING                    4        4     4         4
# FAMILY                    8        8     8         8
# FINANCE                   2        2     2         2
# FOOD_AND_DRINK            2        2     2         2
# LIFESTYLE                 5        5     5         5
# MAPS_AND_NAVIGATION       1        1     1         1
# MEDICAL                   1        1     1         1
# NEWS_AND_MAGAZINES        1        1     1         1
# PERSONALIZATION           1        1     1         1
# PRODUCTIVITY              2        2     2         2
# SHOPPING                  1        1     1         1
# SOCIAL                    1        1     1         1
# SPORTS                    1        1     1         1
# TOOLS                     5        5     5         5
# VIDEO_PLAYERS             2        2     2         2
#                     Rating  Reviews  Size  Installs
# Category
# AUTO_AND_VEHICLES        1        1     1         1
# BUSINESS                 5        5     5         5
# COMMUNICATION            3        3     3         3
# DATING                   2        2     2         2
# FAMILY                  12       12    12        12
# FINANCE                  7        7     7         7
# GAME                     2        2     2         2
# HEALTH_AND_FITNESS      11       11    11        11
# LIFESTYLE                6        6     6         6
# MEDICAL                  6        6     6         6
# NEWS_AND_MAGAZINES       2        2     2         2
# PARENTING                1        1     1         1
# PHOTOGRAPHY              2        2     2         2
# PRODUCTIVITY             4        4     4         4
# SHOPPING                 1        1     1         1
# SOCIAL                   1        1     1         1
# SPORTS                   2        2     2         2
# TOOLS                   12       12    12        12
# TRAVEL_AND_LOCAL         3        3     3         3
# VIDEO_PLAYERS            1        1     1         1
#                      Rating  Reviews  Size  Installs
# Category
# AUTO_AND_VEHICLES         2        2     2         2
# BEAUTY                    1        1     1         1
# BOOKS_AND_REFERENCE       2        2     2         2
# BUSINESS                 12       12    12        12
# COMICS                    1        1     1         1
# COMMUNICATION             3        3     3         3
# DATING                   12       12    12        12
# EVENTS                    2        2     2         2
# FAMILY                   23       23    23        23
# FINANCE                  11       11    11        11
# FOOD_AND_DRINK            2        2     2         2
# GAME                      5        5     5         5
# HEALTH_AND_FITNESS       10       10    10        10
# HOUSE_AND_HOME            1        1     1         1
# LIFESTYLE                13       13    13        13
# MAPS_AND_NAVIGATION       6        6     6         6
# MEDICAL                  14       14    14        14
# NEWS_AND_MAGAZINES        9        9     9         9
# PERSONALIZATION           3        3     3         3
# PHOTOGRAPHY              10       10    10        10
# PRODUCTIVITY             10       10    10        10
# SOCIAL                    1        1     1         1
# SPORTS                    4        4     4         4
# TOOLS                    28       28    28        28
# TRAVEL_AND_LOCAL          5        5     5         5
# VIDEO_PLAYERS             3        3     3         3
#                      Rating  Reviews  Size  Installs
# Category
# ART_AND_DESIGN            3        3     3         3
# AUTO_AND_VEHICLES         5        5     5         5
# BEAUTY                    1        1     1         1
# BOOKS_AND_REFERENCE      14       14    14        14
# BUSINESS                 36       36    36        36
# COMICS                    8        8     8         8
# COMMUNICATION            15       15    15        15
# DATING                   22       22    22        22
# ENTERTAINMENT             4        4     4         4
# FAMILY                  100      100   100       100
# FINANCE                  16       16    16        16
# FOOD_AND_DRINK            7        7     7         7
# GAME                     25       25    25        25
# HEALTH_AND_FITNESS       12       12    12        12
# HOUSE_AND_HOME            4        4     4         4
# LIBRARIES_AND_DEMO        4        4     4         4
# LIFESTYLE                25       25    25        25
# MAPS_AND_NAVIGATION      11       11    11        11
# MEDICAL                  28       28    28        28
# NEWS_AND_MAGAZINES       13       13    13        13
# PARENTING                 1        1     1         1
# PERSONALIZATION          11       11    11        11
# PHOTOGRAPHY              15       15    15        15
# PRODUCTIVITY             16       16    16        16
# SHOPPING                  9        9     9         9
# SOCIAL                   10       10    10        10
# SPORTS                   16       16    16        16
# TOOLS                    67       67    67        67
# TRAVEL_AND_LOCAL         23       23    23        23
# VIDEO_PLAYERS            14       14    14        14
# WEATHER                   2        2     2         2
#                      Rating  Reviews  Size  Installs
# Category
# ART_AND_DESIGN            5        5     5         5
# AUTO_AND_VEHICLES        13       13    13        13
# BEAUTY                    9        9     9         9
# BOOKS_AND_REFERENCE      35       35    35        35
# BUSINESS                 68       68    68        68
# COMICS                    9        9     9         9
# COMMUNICATION            52       52    52        52
# DATING                   44       44    44        44
# EDUCATION                 6        6     6         6
# ENTERTAINMENT            37       37    37        37
# EVENTS                    4        4     4         4
# FAMILY                  322      322   322       322
# FINANCE                  50       50    50        50
# FOOD_AND_DRINK           21       21    21        21
# GAME                    127      127   127       127
# HEALTH_AND_FITNESS       27       27    27        27
# HOUSE_AND_HOME           14       14    14        14
# LIBRARIES_AND_DEMO       17       17    17        17
# LIFESTYLE                72       72    72        72
# MAPS_AND_NAVIGATION      27       27    27        27
# MEDICAL                  77       77    77        77
# NEWS_AND_MAGAZINES       50       50    50        50
# PARENTING                 9        9     9         9
# PERSONALIZATION          37       37    37        37
# PHOTOGRAPHY              34       34    34        34
# PRODUCTIVITY             48       48    48        48
# SHOPPING                 23       23    23        23
# SOCIAL                   27       27    27        27
# SPORTS                   42       42    42        42
# TOOLS                   143      143   143       143
# TRAVEL_AND_LOCAL         39       39    39        39
# VIDEO_PLAYERS            39       39    39        39
# WEATHER                  15       15    15        15
#                      Rating  Reviews  Size  Installs
# Category
# ART_AND_DESIGN           29       29    29        29
# AUTO_AND_VEHICLES        35       35    35        35
# BEAUTY                   23       23    23        23
# BOOKS_AND_REFERENCE      77       77    77        77
# BUSINESS                205      205   205       205
# COMICS                   19       19    19        19
# COMMUNICATION           245      245   245       245
# DATING                  105      105   105       105
# EDUCATION                80       80    80        80
# ENTERTAINMENT            87       87    87        87
# EVENTS                   24       24    24        24
# FAMILY                  887      887   887       887
# FINANCE                 154      154   154       154
# FOOD_AND_DRINK           49       49    49        49
# GAME                    582      582   582       582
# HEALTH_AND_FITNESS      107      107   107       107
# HOUSE_AND_HOME           41       41    41        41
# LIBRARIES_AND_DEMO       47       47    47        47
# LIFESTYLE               133      133   133       133
# MAPS_AND_NAVIGATION      64       64    64        64
# MEDICAL                 156      156   156       156
# NEWS_AND_MAGAZINES      133      133   133       133
# PARENTING                23       23    23        23
# PERSONALIZATION         190      190   190       190
# PHOTOGRAPHY             185      185   185       185
# PRODUCTIVITY            210      210   210       210
# SHOPPING                142      142   142       142
# SOCIAL                  164      164   164       164
# SPORTS                  203      203   203       203
# TOOLS                   379      379   379       379
# TRAVEL_AND_LOCAL        130      130   130       130
# VIDEO_PLAYERS            75       75    75        75
# WEATHER                  41       41    41        41
#                      Rating  Reviews  Size  Installs
# Category
# ART_AND_DESIGN           26       26    26        26
# AUTO_AND_VEHICLES        29       29    29        29
# BEAUTY                   19       19    19        19
# BOOKS_AND_REFERENCE      96       96    96        96
# BUSINESS                105      105   105       105
# COMICS                   21       21    21        21
# COMMUNICATION            63       63    63        63
# DATING                   35       35    35        35
# EDUCATION                70       70    70        70
# ENTERTAINMENT            21       21    21        21
# EVENTS                   28       28    28        28
# FAMILY                  549      549   549       549
# FINANCE                 114      114   114       114
# FOOD_AND_DRINK           44       44    44        44
# GAME                    389      389   389       389
# HEALTH_AND_FITNESS      159      159   159       159
# HOUSE_AND_HOME           28       28    28        28
# LIBRARIES_AND_DEMO       15       15    15        15
# LIFESTYLE                98       98    98        98
# MAPS_AND_NAVIGATION      28       28    28        28
# MEDICAL                 144      144   144       144
# NEWS_AND_MAGAZINES       68       68    68        68
# PARENTING                25       25    25        25
# PERSONALIZATION         138      138   138       138
# PHOTOGRAPHY              82       82    82        82
# PRODUCTIVITY            124      124   124       124
# SHOPPING                 78       78    78        78
# SOCIAL                   79       79    79        79
# SPORTS                  110      110   110       110
# TOOLS                   187      187   187       187
# TRAVEL_AND_LOCAL         54       54    54        54
# VIDEO_PLAYERS            41       41    41        41
# WEATHER                  24       24    24        24
#                   Category    Rating   Reviews      Size  Installs
# 0           ART_AND_DESIGN  4.100000  1.410987  4.100000  1.410987
# 1           ART_AND_DESIGN  3.900000  1.360977  3.900000  1.360977
# 2           ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 3           ART_AND_DESIGN  4.500000  1.504077  4.500000  1.504077
# 4           ART_AND_DESIGN  4.300000  1.458615  4.300000  1.458615
# 5           ART_AND_DESIGN  4.400000  1.481605  4.400000  1.481605
# 6           ART_AND_DESIGN  3.800000  1.335001  3.800000  1.335001
# 7           ART_AND_DESIGN  4.100000  1.410987  4.100000  1.410987
# 8           ART_AND_DESIGN  4.400000  1.481605  4.400000  1.481605
# 9           ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 10          ART_AND_DESIGN  4.400000  1.481605  4.400000  1.481605
# 11          ART_AND_DESIGN  4.400000  1.481605  4.400000  1.481605
# 12          ART_AND_DESIGN  4.200000  1.435085  4.200000  1.435085
# 13          ART_AND_DESIGN  4.600000  1.526056  4.600000  1.526056
# 14          ART_AND_DESIGN  4.400000  1.481605  4.400000  1.481605
# 15          ART_AND_DESIGN  3.200000  1.163151  3.200000  1.163151
# 16          ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 17          ART_AND_DESIGN  4.500000  1.504077  4.500000  1.504077
# 18          ART_AND_DESIGN  4.300000  1.458615  4.300000  1.458615
# 19          ART_AND_DESIGN  4.600000  1.526056  4.600000  1.526056
# 20          ART_AND_DESIGN  4.000000  1.386294  4.000000  1.386294
# 21          ART_AND_DESIGN  4.100000  1.410987  4.100000  1.410987
# 22          ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 23          ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 24          ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 25          ART_AND_DESIGN  4.800000  1.568616  4.800000  1.568616
# 26          ART_AND_DESIGN  4.700000  1.547563  4.700000  1.547563
# 27          ART_AND_DESIGN  4.100000  1.410987  4.100000  1.410987
# 28          ART_AND_DESIGN  3.900000  1.360977  3.900000  1.360977
# 29          ART_AND_DESIGN  4.100000  1.410987  4.100000  1.410987
# ...                    ...       ...       ...       ...       ...
# 10811    AUTO_AND_VEHICLES  4.450000  1.492904  4.450000  1.492904
# 10812               FAMILY  4.100000  1.410987  4.100000  1.410987
# 10813             BUSINESS  4.050000  1.398717  4.050000  1.398717
# 10814               FAMILY  4.000000  1.386294  4.000000  1.386294
# 10815  BOOKS_AND_REFERENCE  4.200000  1.435085  4.200000  1.435085
# 10816             BUSINESS  4.100000  1.410987  4.100000  1.410987
# 10817                TOOLS  4.000000  1.386294  4.000000  1.386294
# 10818              FINANCE  3.650000  1.294727  3.650000  1.294727
# 10819  BOOKS_AND_REFERENCE  3.300000  1.193922  3.300000  1.193922
# 10820               FAMILY  5.000000  1.609438  5.000000  1.609438
# 10821               FAMILY  4.833333  1.575536  4.833333  1.575536
# 10822         PRODUCTIVITY  4.666667  1.540445  4.666667  1.540445
# 10823        VIDEO_PLAYERS  4.500000  1.504077  4.500000  1.504077
# 10824              MEDICAL  4.333333  1.466337  4.333333  1.466337
# 10825               SOCIAL  4.166667  1.427116  4.166667  1.427116
# 10826               SOCIAL  4.000000  1.386294  4.000000  1.386294
# 10827               FAMILY  4.200000  1.435085  4.200000  1.435085
# 10828               COMICS  3.400000  1.223775  3.400000  1.223775
# 10829  BOOKS_AND_REFERENCE  4.600000  1.526056  4.600000  1.526056
# 10830   NEWS_AND_MAGAZINES  3.800000  1.335001  3.800000  1.335001
# 10831  MAPS_AND_NAVIGATION  3.800000  1.335001  3.800000  1.335001
# 10832              WEATHER  3.800000  1.335001  3.800000  1.335001
# 10833  BOOKS_AND_REFERENCE  4.800000  1.568616  4.800000  1.568616
# 10834               FAMILY  4.000000  1.386294  4.000000  1.386294
# 10835             BUSINESS  4.250000  1.446919  4.250000  1.446919
# 10836               FAMILY  4.500000  1.504077  4.500000  1.504077
# 10837               FAMILY  5.000000  1.609438  5.000000  1.609438
# 10838              MEDICAL  4.750000  1.558145  4.750000  1.558145
# 10839  BOOKS_AND_REFERENCE  4.500000  1.504077  4.500000  1.504077
# 10840            LIFESTYLE  4.500000  1.504077  4.500000  1.504077
#
# [10840 rows x 5 columns]

# %%
#which category has the highest rating mean?
#show the plot
A=[]
B=[]
change=df1.groupby('Category')
#sns.relplot(x='Category',y='Rating',data=dataset)
for i in change:
#    print(i[1]['Rating'])
    A.append(i[1]['Rating'].mean(axis=None,skipna=True))
    B.append(i[0])
#    sns.relplot(x='Category',y=,data=dataset)
A=A[1:]
B=B[1:]
#print(A,B)
#print(list(range(len(B))))
plt.scatter(list(range(len(B))),A,c='r',marker='o')
plt.xticks(list(range(len(B))), B, rotation=270)
plt.show()

#which category?
print(B[A.index(max(A))])
# Out:
# EVENTS

# %%
df_new = change.mean().iloc[1:]
# df_new.plot(kind='bar', color=plt.cm.Paired(np.arange(len(df_new))))
plt.figure()
plt.scatter(x=range(len(df_new)), y=df_new['Rating'], c=df_new['Rating'])
plt.xticks(list(range(len(B))), B, rotation=270)
#plt.bar(df_new.index, df_new['Rating'].values, color=plt.cm.Paired(np.arange(len(df_new))))
plt.show()
#print(df_new['Rating'])

# %%
#which category has the highest rating mean?
#show the plot
A=[]
B=[]
change=df1.groupby('Category')
#sns.relplot(x='Category',y='Rating',data=dataset)
for i in change:
#    print(i[1]['Rating'])
    A.append(i[1]['Rating'].mean(axis=None,skipna=True))
    B.append(i[0])
#    sns.relplot(x='Category',y=,data=dataset)
A=A[1:]
B=B[1:]
#print(A,B)
#print(list(range(len(B))))
plt.bar(df_new.index, df_new['Rating'].values, color=plt.cm.Paired(np.arange(len(df_new))))
plt.xticks(list(range(len(B))), B, rotation=270)
plt.title('title')
# plt.show()

#which category?
print(B[A.index(max(A))])
# df_new = change.mean().iloc[1:]
# # df_new.plot(kind='bar', color=plt.cm.Paired(np.arange(len(df_new))))
# plt.figure()
# plt.scatter(x=range(len(df_new)), y=df_new['Rating'], c=df_new['Rating'])
# plt.xticks(list(range(len(B))), B, rotation=270)
# #plt.bar(df_new.index, df_new['Rating'].values, color=plt.cm.Paired(np.arange(len(df_new))))
# plt.show()
# print(df_new['Rating'])
# Out:
# EVENTS

# %%
#For each Rating period, which category is the most?
#  First of all, plot the number of each category for each rating period
Lis2=['1.0-1.5','1.5-2.0','2.0-2.5','2.5-3.0','3.0-3.5','3.5-4.0','4.0-4.5','4.5-5.0']
for i in range(len(Lis)):
    C=[]
    D=[]
    new=Lis[i].groupby('Category')
    for j in new:
#         print(j[1].count()['Rating'])
        D.append(j[1].count()['Rating'])
        C.append(j[0])
#     print(C,D)
    X=list(range(len(C)))
    Y=D
    df_new1 = new.count()
#    print(df_new1)
    plt.figure()
    plt.scatter(x=range(len(df_new1)), y=df_new1['Rating'], c=df_new1['Rating'],marker='*')
#    plt.scatter(X,Y,marker='*')
    plt.xlabel('Category')
    plt.ylabel('Number')
    plt.title(Lis2[i])
    plt.xticks(list(range(len(C))), C, rotation=270)
    plt.show()
#  Secondly, which category has the highest number?
    print(C[D.index(max(D))])
#         print(j[0])
#         X=list(range(len(j[0])))
#         Y=j[1].count()['Rating']
#        print(X,Y)
#         plt.plot(X,Y)
#     plt.show()
# Out:
# TOOLS
# FAMILY
# FAMILY
# TOOLS
# FAMILY
# FAMILY
# FAMILY
# FAMILY

# %%
#For each Rating period, which category is the most?
#  First of all, plot the number of each category for each rating period
Lis2=['1.0-1.5','1.5-2.0','2.0-2.5','2.5-3.0','3.0-3.5','3.5-4.0','4.0-4.5','4.5-5.0']
for i in range(len(Lis)):
    C=[]
    D=[]
    new=Lis[i].groupby('Category')
    for j in new:
#         print(j[1].count()['Rating'])
        D.append(j[1].count()['Rating'])
        C.append(j[0])
#     print(C,D)
    X=list(range(len(C)))
    Y=D
    df_new1 = new.count()    
    plt.bar(df_new1.index, df_new1['Rating'].values, color=plt.cm.Paired(np.arange(len(df_new1))))
#    plt.bar(X,Y,color='r')
    plt.xlabel('Category')
    plt.ylabel('Number')
    plt.title(Lis2[i])
    plt.xticks(list(range(len(C))), C, rotation=270)
    plt.show()
#  Secondly, which category has the highest number?
    print(C[D.index(max(D))])
#         print(j[0])
#         X=list(range(len(j[0])))
#         Y=j[1].count()['Rating']
#        print(X,Y)
#         plt.plot(X,Y)
#     plt.show()
# Out:
# TOOLS
# FAMILY
# FAMILY
# TOOLS
# FAMILY
# FAMILY
# FAMILY
# FAMILY

# %%
#df_new.reset_index()

# %%
#what is the possible relationship between the Reviews and Installs?
#sns.relplot(x='Reviews', y='Installs', data=df1.head(1000))
sns.regplot(x='Reviews', y='Installs', data=df1.head(1000),fit_reg=True)

#It is in a linear way. It has a positive relationship that if reviews amount is high enough then the Installs amount is also high.
# Out:
# F:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#What about the others? Let's see the pairplots

sns.pairplot(data=df1,hue='Category')
# Out:
# F:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
palette=sns.diverging_palette(220,10,as_cmap=True)
sns.relplot(x='Reviews',y='Installs', hue='Rating',palette=palette, size='Size', data=df1)

# %%
corr=df1.corr()
corr
# Out:
#             Rating   Reviews      Size  Installs
# Rating    1.000000  0.980358  1.000000  0.980358
# Reviews   0.980358  1.000000  0.980358  1.000000
# Size      1.000000  0.980358  1.000000  0.980358
# Installs  0.980358  1.000000  0.980358  1.000000

# %%
mask=np.zeros((4,4), dtype=np.bool) #Creating a mask to hide the upper traingle of the corr array
mask[np.triu_indices_from(mask)]=True
mask
# Out:
# array([[ True,  True,  True,  True],
#        [False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False,  True]])

# %%
sns.heatmap(np.abs(corr),cmap=palette,mask=mask)
 #Presenting correlation coefficients on the heatmap, using mask to hide redunant or irrelevant cells
